# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset("/Users/smurugan9/research/aislens/AISLENS/data/processed/draft_dependence_changepoint/ruptures_draftDepenBasalMelt_parameters_filled_prepped.nc")

# %%
ds_thw = xr.open_dataset("/Users/smurugan9/research/aislens/AISLENS/data/interim/draft_dependence/satobs/comprehensive/draftDepenBasalMelt_comprehensive_Thwaites.nc")

# %%
ds.draftDepenBasalMelt_constantMeltValue.plot()

# %%
ds.draftDepenBasalMelt_constantMeltValue.plot()
