# %%
# Define relative directory paths and file names

# %%
# Setup forcing file and initial conditions files for AISLENS simulations

# %%
# TODO - Add code to create the forcing file and initial conditions files for AISLENS simulations

# %% [markdown]
# ## AISLENS_ctrl_constant.nc
#
# Constant floating ice shelf basal mass balance forcing
#
# ## AISLENS_ctrl_draftDepen.nc
#
# Constant mean i
#
# ## AISLENS_ctrl_draftDepen_fullIS.nc
# (Extrapolate draft dependent melt parameterizations to the interior of the ice sheet)
#
#
# ## AISLENS_ctrl_variability.nc
#
# ## AISLENS_ctrl_variability_fullIS.nc
#
# (Extrapolate draft dependent parameterization and variability to the interior of the ice sheet)
