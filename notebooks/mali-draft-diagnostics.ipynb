# %% [markdown]
# This notebook includes diagnostic tests to identify and tune the draft dependence function. There are different methods that can be used to tune these parameters. To keep it simple, this notebook lists out a few and compares them based on a validation metric (i.e., the method that is able to closely match the observed cumulative melt across the most number of ice shelves, particularly the important ones with greater absolute values of the cumulative melt).

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
from aislens.config import config
from pathlib import Path

# %%
ctrl_outputstate2000 = xr.open_dataset("/Users/smurugan9/research/aislens/AISLENS/data/MALI/ENSEMBLES/CTRL/EM8/output_state_2000.nc")
ctrl_outputflux2000 = xr.open_dataset("/Users/smurugan9/research/aislens/AISLENS/data/MALI/ENSEMBLES/CTRL/EM8/output_flux_all_timesteps_2000.nc")
icems = gpd.read_file(config.FILE_ICESHELFMASKS);

# %%
satobs = xr.open_dataset(config.FILE_PAOLO23_SATOBS, chunks={config.TIME_DIM: 36})
